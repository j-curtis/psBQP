# %%
import numpy as np
import pickle
import os

# %%
import sys
_demler_tools_path = '/home/filip/Git_Code'

sys.path.append(_demler_tools_path) #path to the demler_tools

from demler_tools.file_manager import path_management, file_management_local_backend
from demler_tools.file_manager import file_management,cluster_backend_tools
from demler_tools.parallelization import cluster_interface, resource_estimation,troubleshooting_tools

path_management.initialize(project_name = 'psBQP-keldysh')


crt_simulations_machine = 'cluster_euler'
crt_controlling_machine = 'laptop'
# Out:
# Successfully initialized path management with following parameters:
#      username:                fmarijanovic
#      project name:            psBQP-keldysh
#      controlling machine:     laptop
#      library version:         v2.3.0-beta-17-g6b0081d
#      auto SSH transfer:       True
#      default save location:   /home/filip/Documents/Research/data_files/
#      LTS mount point:         /home/filip
#      email domain:            phys.ethz.ch
#      cluster OS:              Ubuntu
#      cluster partition:       work
#      SSH host file:           /home/filip/.ssh/known_hosts
#      SSH key file:            /home/filip/.ssh/id_ed25519_euler
#      default modules:         {'CentOS': 'gcc/8.2.0 python/3.11.2', 'Ubuntu': 'stack/2024-06 python/3.11.6'}

# %%
file_management.display_all_folders(machine_identifier = crt_simulations_machine, folder_summaries = True)
# Out:
# Directory with timestamp 1781551045 has status: submitted.
#
#       Human-readable file created at Mon Jun 15 21:17:25 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Quenching temperature test
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun 15 21:17:54 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 21:17:54 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3498260
#       [Mon Jun 15 21:17:56 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3498262
#
#
#
# Directory with timestamp 1781551032 has status: submitted.
#
#       Human-readable file created at Mon Jun 15 21:17:12 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 24
#
#       Task summary: Quenching temperature test
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun 15 21:17:40 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 21:17:41 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3498236
#       [Mon Jun 15 21:17:51 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3498241
#
#
#
# Directory with timestamp 1781550786 has status: submitted.
#
#       Human-readable file created at Mon Jun 15 21:13:06 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 24
#
#       Task summary: Computing the Temperature dependence of the equilibrium state for future reference
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun 15 21:13:25 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 21:13:26 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3497764
#       [Mon Jun 15 21:13:28 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3497766
#
#
#
# Directory with timestamp 1781550498 has status: submitted.
#
#       Human-readable file created at Mon Jun 15 21:08:18 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Linear response
#       Number of jobs to run: 16
#
#       Task summary: Testing new equilibration and current
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun 15 21:08:45 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 21:08:46 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3497411
#       [Mon Jun 15 21:08:49 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3497413
#
#
#
# Directory with timestamp 1781550445 has status: submitted.
#
#       Human-readable file created at Mon Jun 15 21:07:25 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Computing the equilibrium state for future reference
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun 15 21:08:41 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 21:08:41 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3497407
#       [Mon Jun 15 21:08:43 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3497410
#
#
#
# Directory with timestamp 1781534526 has status: completed.
#
#       Human-readable file created at Mon Jun 15 16:42:06 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Linear response
#       Number of jobs to run: 1
#
#       Task summary: Testing new equilibration and current
#
#       Current folder state: completed
#
#       Calculation log:
#       [Mon Jun 15 16:47:30 2026] Updated directory state to the following: submitted
#       [Mon Jun 15 16:47:30 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 3469986
#       [Mon Jun 15 16:47:35 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 3469991
#       [Mon Jun 15 21:35:51 2026] Recovered slurm metadata for job ID: 3469986
#       [Mon Jun 15 21:35:51 2026] Confirmed presence of all result files in folder.
#       [Mon Jun 15 21:35:51 2026] Total size of present result files: 412.59 MB
#       [Mon Jun 15 21:35:51 2026] Total size of directory: 432647062 bytes
#       [Mon Jun 15 21:35:51 2026] Updated directory state to the following: completed

# %%
cluster_interface.retrieve_completed_folders(source_machine_identifier = crt_simulations_machine, target_machine_identifier = crt_controlling_machine, visual_progress = True, archive_remote=True)
# Out:
# Successfully copied directory 1781534526 to autoarchive path.
#   0%|          | 0.01/412.6 MB [00:00<1:46:57, 15.56s/MB]ERROR:demler_tools.file_manager.basic_remote_tools:Garbage packet received
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 799, in getfo
#     return self._transfer_with_callback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 678, in _transfer_with_callback
#     data = reader.read(32768)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/file.py", line 203, in read
#     new_data = self._read(read_size)
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_file.py", line 182, in _read
#     data = self._read_prefetch(size)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_file.py", line 162, in _read_prefetch
#     self.sftp._read_response()
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 887, in _read_response
#     t, data = self._read_packet()
#               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp.py", line 218, in _read_packet
#     data = self._read_all(size)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp.py", line 196, in _read_all
#     x = self.sock.recv(n)
#         ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/channel.py", line 697, in recv
#     out = self.in_buffer.read(nbytes, self.timeout)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/buffered_pipe.py", line 150, in read
#     self._cv.wait(timeout)
#   File "/usr/lib/python3.11/threading.py", line 320, in wait
#     waiter.acquire()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/filip/Git_Code/demler_tools/file_manager/basic_remote_tools.py", line 537, in run_remote_method
#     return method(ssh_object = ssh, sftp_object = sftp, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/filip/Git_Code/demler_tools/file_manager/cluster_backend_tools.py", line 408, in find_and_recover_completed
#     recover_single_directory(ssh_object = ssh_object, sftp_object = sftp_object, timestamp = timestamp, source_machine_identifier = source_machine_identifier, target_machine_identifier = target_machine_identifier,
#   File "/home/filip/Git_Code/demler_tools/file_manager/cluster_backend_tools.py", line 372, in recover_single_directory
#     sftp_object.download_data(source_path = dir_path, target_parent_directory = path_management.default_simulation_data_path(target_machine_identifier), visual_progress = visual_progress,
#   File "/home/filip/Git_Code/demler_tools/file_manager/basic_remote_tools.py", line 425, in download_data
#     self.get(os.path.join(source_parent_directory, file_name), os.path.join(target_parent_directory, file_name))
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 840, in get
#     size = self.getfo(
#            ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 796, in getfo
#     with self.open(remotepath, "rb") as fr:
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/util.py", line 290, in __exit__
#     self.close()
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_file.py", line 82, in close
#     self._close(async_=False)
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_file.py", line 104, in _close
#     self.sftp._request(CMD_CLOSE, self.handle)
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 857, in _request
#     return self._read_response(num)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 887, in _read_response
#     t, data = self._read_packet()
#               ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp.py", line 216, in _read_packet
#     raise SFTPError("Garbage packet received")
# paramiko.sftp.SFTPError: Garbage packet received
#   0%|          | 0.01/412.6 MB [00:55<631:25:30, 5509.42s/MB]
# [run_remote_method] The following exception came up when trying to run the method:
#
# Garbage packet received

# %%
file_management.display_problematic_folders(machine_identifier = crt_simulations_machine, folder_summaries = False)
# Out:
# Directory with timestamp 1780919727 has status: problematic.
# Directory with timestamp 1780919661 has status: problematic.

# %%
_timestamp_to_correct = 1780919727

# %%
new_bash_needed = troubleshooting_tools.directory_troubleshoot(timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine, show_errors = True)
# Out:
# Diagnosing directory 1780919727:
# ERROR:demler_tools.file_manager.basic_remote_tools:[Errno 2] No such file
# Traceback (most recent call last):
#   File "/home/filip/Git_Code/demler_tools/file_manager/basic_remote_tools.py", line 537, in run_remote_method
#     return method(ssh_object = ssh, sftp_object = sftp, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/filip/Git_Code/demler_tools/parallelization/troubleshooting_tools.py", line 119, in troubleshoot_backend
#     memory_jobs, time_jobs, error_jobs, unknown_jobs = scan_jsr(ssh_object = ssh_object, sftp_object = sftp_object, folder_path = folder_path)
#                                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/filip/Git_Code/demler_tools/parallelization/troubleshooting_tools.py", line 79, in scan_jsr
#     with sftp_object.file(os.path.join(folder_path, path_management.job_status_filetag()), 'rb') as js_reg:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 372, in open
#     t, msg = self._request(CMD_OPEN, filename, imode, attrblock)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 857, in _request
#     return self._read_response(num)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 909, in _read_response
#     self._convert_status(msg)
#   File "/usr/local/lib/python3.11/dist-packages/paramiko/sftp_client.py", line 938, in _convert_status
#     raise IOError(errno.ENOENT, text)
# FileNotFoundError: [Errno 2] No such file
# [run_remote_method] The following exception came up when trying to run the method:
#
# [Errno 2] No such file

# %%
if new_bash_needed:
    
    troubleshooting_tools.rewrite_bash_file(new_time = (4,0,0,0), new_memory_value = 2, new_memory_unit = 'G', timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine)

else:
        
    print('The code does not think a new bash file is necessary.')
# Out:
# The code does not think a new bash file is necessary.

# %%
troubleshooting_tools.mark_for_resubmission(timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine)

# %%
file_management.display_folders_to_resubmit(machine_identifier = crt_simulations_machine, folder_summaries = False)
# Out:
# No unattempted folders were found on the cluster.

# %%
cluster_interface.push_correction_folders(machine_identifier = crt_simulations_machine, override_checks = False)
# Out:
# No unattempted folders were found on the cluster.

# %%
# Out:
# No unattempted folders were found on the cluster.

# %%
# Out:
# No unattempted folders were found on the cluster.
