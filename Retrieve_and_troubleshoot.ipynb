# %%
import numpy as np
import pickle
import os

# %%
import sys
_demler_tools_path = '/home/filip/Git_Code'

sys.path.append(_demler_tools_path) #path to the demler_tools

from demler_tools.file_manager import path_management, file_management_local_backend
from demler_tools.file_manager import file_management,cluster_backend_tools
from demler_tools.parallelization import cluster_interface, resource_estimation,troubleshooting_tools

path_management.initialize(project_name = 'psBQP-keldysh')


crt_simulations_machine = 'cluster_euler'
crt_controlling_machine = 'laptop'
# Out:
# Successfully initialized path management with following parameters:
#      username:                fmarijanovic
#      project name:            psBQP-keldysh
#      controlling machine:     laptop
#      library version:         v2.3.0-beta-17-g6b0081d
#      auto SSH transfer:       True
#      default save location:   /home/filip/Documents/Research/data_files/
#      LTS mount point:         /home/filip
#      email domain:            phys.ethz.ch
#      cluster OS:              Ubuntu
#      cluster partition:       work
#      SSH host file:           /home/filip/.ssh/known_hosts
#      SSH key file:            /home/filip/.ssh/id_ed25519_euler
#      default modules:         {'CentOS': 'gcc/8.2.0 python/3.11.2', 'Ubuntu': 'stack/2024-06 python/3.11.6'}

# %%
file_management.display_all_folders(machine_identifier = crt_simulations_machine, folder_summaries = True)
# Out:
# Directory with timestamp 1780909551 has status: problematic.
# The auto postprocessor found an issue with this directory! Please troubleshoot.
#
#       Human-readable file created at Mon Jun  8 11:05:51 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Computing the equilibrium state for future reference
#
#       Current folder state: problematic
#
#       Calculation log:
#       [Mon Jun  8 11:06:10 2026] Updated directory state to the following: submitted
#       [Mon Jun  8 11:06:10 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 2534866
#       [Mon Jun  8 11:06:11 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 2534876
#       [Mon Jun  8 11:08:01 2026] Recovered slurm metadata for job ID: 2534866
#       [Mon Jun  8 11:08:01 2026] Not all expected results were found in directory. Investigating...
#       [Mon Jun  8 11:08:01 2026] Updated directory state to the following: problematic
#       [Mon Jun  8 11:08:02 2026] The following jobs were found to be out of memory: [0]
#
#
#
# Directory with timestamp 1780909313 has status: completed.
#
#       Human-readable file created at Mon Jun  8 11:01:53 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Computing the equilibrium state for future reference
#
#       Current folder state: completed
#
#       Calculation log:
#       [Mon Jun  8 11:02:05 2026] Updated directory state to the following: submitted
#       [Mon Jun  8 11:02:06 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 2534249
#       [Mon Jun  8 11:02:09 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 2534252
#       [Mon Jun  8 11:03:48 2026] Recovered slurm metadata for job ID: 2534249
#       [Mon Jun  8 11:03:48 2026] Confirmed presence of all result files in folder.
#       [Mon Jun  8 11:03:48 2026] Total size of present result files: 1.25 MB
#       [Mon Jun  8 11:03:48 2026] Total size of directory: 1319590 bytes
#       [Mon Jun  8 11:03:48 2026] Updated directory state to the following: completed
#
#
#
# Directory with timestamp 1780908833 has status: problematic.
# The auto postprocessor found an issue with this directory! Please troubleshoot.
#
#       Human-readable file created at Mon Jun  8 10:53:53 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Computing the equilibrium state for future reference
#
#       Current folder state: problematic
#
#       Calculation log:
#       [Mon Jun  8 10:54:05 2026] Updated directory state to the following: submitted
#       [Mon Jun  8 10:54:06 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 2533090
#       [Mon Jun  8 10:54:07 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 2533091
#       [Mon Jun  8 10:57:30 2026] Recovered slurm metadata for job ID: 2533090
#       [Mon Jun  8 10:57:30 2026] Not all expected results were found in directory. Investigating...
#       [Mon Jun  8 10:57:31 2026] Updated directory state to the following: problematic
#       [Mon Jun  8 10:57:31 2026] The following jobs failed for unknown reasons: [0]
#
#
#
# Directory with timestamp 1780907499 has status: submitted.
#
#       Human-readable file created at Mon Jun  8 10:31:39 2026, using demler_tools v2.3.0-beta-17-g6b0081d
#       Path convention: v3
#       Created by user: fmarijanovic
#       Project name: psBQP-keldysh
#
#       Calculation type: Equilibration
#       Number of jobs to run: 1
#
#       Task summary: Computing the equilibrium state for future reference
#
#       Current folder state: submitted
#
#       Calculation log:
#       [Mon Jun  8 10:31:48 2026] Updated directory state to the following: submitted
#       [Mon Jun  8 10:31:48 2026] Submitted folder job to cluster with controller cluster_files/cluster_control_0_main.sh and under ID: 2529433
#       [Mon Jun  8 10:31:50 2026] Submitted automatic postprocess job to cluster with controller cluster_files/cluster_control_0_post.sh and under ID: 2529437

# %%
cluster_interface.retrieve_completed_folders(source_machine_identifier = crt_simulations_machine, target_machine_identifier = crt_controlling_machine, visual_progress = True, archive_remote=True)
# Out:
# Successfully copied directory 1780908007 to autoarchive path.
# 100%|██████████| 1.26/1.26 MB [00:01<00:00,  1.36s/MB]

# %%
file_management.display_problematic_folders(machine_identifier = crt_simulations_machine, folder_summaries = False)

# %%
_timestamp_to_correct = 1759396792

# %%
new_bash_needed = troubleshooting_tools.directory_troubleshoot(timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine, show_errors = True)

# %%
if new_bash_needed:
    
    troubleshooting_tools.rewrite_bash_file(new_time = (4,0,0,0), new_memory_value = 2, new_memory_unit = 'G', timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine)

else:
        
    print('The code does not think a new bash file is necessary.')

# %%
troubleshooting_tools.mark_for_resubmission(timestamp = _timestamp_to_correct, machine_identifier = crt_simulations_machine)

# %%
file_management.display_folders_to_resubmit(machine_identifier = crt_simulations_machine, folder_summaries = False)
# Out:
# No unattempted folders were found on the cluster.

# %%
cluster_interface.push_correction_folders(machine_identifier = crt_simulations_machine, override_checks = False)
# Out:
# No unattempted folders were found on the cluster.

# %%
# Out:
# No unattempted folders were found on the cluster.

# %%
# Out:
# No unattempted folders were found on the cluster.
