# %%
import numpy as np
from matplotlib import pyplot as plt 
import time 

plt.rcParams['font.size']=14
plt.rcParams['text.usetex']=True

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parent / "src"))
# Now you can import normally
import Eilenberger as eil
import nambu_support

# %%
ntheta = 20
cutoff = 30.*nambu_support.get_bcs_ratio()
nw = 2000

fine_nw = 200
fine_cutoff = 1.0*nambu_support.get_bcs_ratio()

ntemps = 10
temps = np.linspace(0.1,1.2,ntemps)

gaps = np.zeros((ntemps),dtype=complex)
times = np.zeros_like(gaps,dtype=float)
grs = []

sim = eil.Eilenberger(nw,ntheta,cutoff,fine_grid=(fine_nw,fine_cutoff))
sim.verbose = True
sim.set_gamma_imp(0.3)
#sim.set_Dynes_eta(0.00001)
sim.set_Q0(0.)
sim.set_Tc(1.)
sim.set_BCS_coupling(sim.calc_BCS_coupling() )

sim.scba_step = 0.15
sim.scba_err = 1.e-4

for i in range(ntemps):
    print(str(i))
    sim.set_temperature(temps[i])
    t0 = time.time()
    if i > 0:
        gap, gr  = sim.calc_eq(grs[i-1])
        print(gap)
        gaps[i] = gap
        grs.append(gr)
    else:
        gap, gr = sim.calc_eq()
        print(gap)
        gaps[i] = gap
        grs.append(gr)
    t1 = time.time()
    times[i] = t1-t0
# Out:
# (2, 2, 2201, 20)
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 36
#      34     grs.append(gr)
#      35 else:
# ---> 36     gap, gr = sim.calc_eq()
#      37     print(gap)
#      38     gaps[i] = gap
#
# File ~/Documents/Research/Superconducting_vortices/Keldysh-non-eq/psBQP/Eilenberger.py:443, in Eilenberger.calc_eq(self, gr0)
#     440 def calc_eq(self,gr0=None):
#     441 	### This computes the equilibrium gap and Green's function (optionally) given initial guesses to pass to the solver
# --> 443 	gr = self._calc_gr(self.fd_tensor,self.Q0,gr0)
#     445 	return self._calc_gap(self._rf2g(gr,self.fd_tensor)), gr
#
# File ~/Documents/Research/Superconducting_vortices/Keldysh-non-eq/psBQP/Eilenberger.py:355, in Eilenberger._calc_gr(self, f, Q, gr0, root_method)
#     351 # g as a function of sigma_r and delta
# ...

# %%
plt.plot(temps,np.real(gaps[:]),marker='.')
plt.axhline(0.,color='gray',linestyle='dashed')
plt.axhline(eil.BCS_ratio, color='gray',linestyle='dashed')
plt.show()
plt.plot(temps,times[:])
#plt.yscale('log')
plt.show()

# %%
x = np.linspace(-30,30,1000)
plt.plot(sim.w_arr,np.real(grs[0][0,0,:,0]),'red')
plt.plot(sim.w_arr,np.imag(grs[0][0,0,:,0]),'blue')
plt.show()
